# %%
from dask.distributed import LocalCluster, Client
cluster = LocalCluster()
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:42747' processes=12 threads=96, memory=0.98 TiB>
# 2026-02-12 12:44:19,114 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f4688fe4e00>, <Task finished name='Task-563185' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,122 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f4646abc040>, <Task finished name='Task-563198' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,128 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f468910ed40>, <Task finished name='Task-563200' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,136 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a2d2d620>, <Task finished name='Task-563201' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,168 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f467e828180>, <Task finished name='Task-563241' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,175 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a29134c0>, <Task finished name='Task-563243' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,181 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a342d760>, <Task finished name='Task-563256' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,187 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a342d8a0>, <Task finished name='Task-563257' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,572 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a341fb00>, <Task finished name='Task-563573' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,579 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a342e3e0>, <Task finished name='Task-563585' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,586 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a342dbc0>, <Task finished name='Task-563587' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,592 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a32371a0>, <Task finished name='Task-563589' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,927 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a18cc040>, <Task finished name='Task-563853' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,934 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a3189300>, <Task finished name='Task-563855' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,940 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f4688fe4b80>, <Task finished name='Task-563868' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,947 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a159be20>, <Task finished name='Task-563869' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:20,015 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a1e93ce0>, <Task finished name='Task-563960' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:20,022 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f4688e58d60>, <Task finished name='Task-563973' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:20,030 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f4688fe4b80>, <Task finished name='Task-563975' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:20,037 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f4688fe4c20>, <Task finished name='Task-563976' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:20,400 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a32f59e0>, <Task finished name='Task-564280' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# ...
# 2026-02-12 12:44:21,198 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f4688e58cc0>, <Task finished name='Task-564970' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:21,205 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a1bdea20>, <Task finished name='Task-564974' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:21,211 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a18cdb20>, <Task finished name='Task-564976' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:21,379 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a1ae51c0>, <Task finished name='Task-565105' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:21,385 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f467e828e00>, <Task finished name='Task-565120' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:21,392 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f46a3189300>, <Task finished name='Task-565128' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:21,399 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f467e829580>, <Task finished name='Task-565141' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8

# %% [markdown]
# ### Load MITgcm Output from Assimilations

# %%
foldername = '/home/edavenport/analysis/TPOSE6_VelocityAssim/TPOSE_TAO/OSM_2026/'

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 13
import cmocean.cm as cmo
import xarray as xr
from open_tpose import tpose2012to2013
import numpy as np
import xarray as xr

prefix = ['diag_state','diag_surf']
ds_tpose_noTAO = tpose2012to2013(prefix)

ds_tpose_noTAO['XC'] = ds_tpose_noTAO.XC.astype(float)
ds_tpose_noTAO['YC'] = ds_tpose_noTAO.YC.astype(float)
ds_tpose_noTAO['Z'] = ds_tpose_noTAO.Z.astype(float)
ds_tpose_noTAO['XG'] = ds_tpose_noTAO.XG.astype(float)
ds_tpose_noTAO['YG'] = ds_tpose_noTAO.YG.astype(float)
# Out:
# mar2013/diags_daily/
# may2013/diags_daily/
# jul2013/diags_daily/
# sep2013/diags_daily/
# nov2013/diags_daily/
# Days in 2012-2013: (should be 731)
# 731

# %%
from xmitgcm import open_mdsdataset

data_dir = '/data/SO3/edavenport/tpose6/sep2012/velocity_assim/run_iter22/'
grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

offset = 10
num_diags = 30+31+offset #sep, oct + 10 days
itPerFile = 72 # 1 day
intervals = range(itPerFile,itPerFile*num_diags,itPerFile)

prefix = ['diag_state','diag_surf']
ds = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-09-01',delta_t=1200)

num_diags = 30+31+31+28 # nov, dec, jan, feb (starting from nov 10)
itPerFile = 72 # 1 day
intervals = range(itPerFile*offset,itPerFile*num_diags,itPerFile)

data_dir = '/data/SO3/edavenport/tpose6/nov2012/run_iter20/'
ds_new = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=intervals,prefix=prefix,ref_date='2012-11-01',delta_t=1200)

ds_tpose_TAO = xr.concat([ds,ds_new],dim='time')

ds_tpose_TAO['XC'] = ds_tpose_TAO.XC.astype(float)
ds_tpose_TAO['YC'] = ds_tpose_TAO.YC.astype(float)
ds_tpose_TAO['Z'] = ds_tpose_TAO.Z.astype(float)
ds_tpose_TAO['XG'] = ds_tpose_TAO.XG.astype(float)
ds_tpose_TAO['YG'] = ds_tpose_TAO.YG.astype(float)

# %% [markdown]
# ### Load TAO U and V

# %%
lon_str = '140'
TAO_ADCP_file = '/data/SO3/edavenport/TAO_2012to2016_daily/ADCP_2012to2016_0N' + lon_str + 'W_daily.cdf' 
dsTAO_140 = xr.open_dataset(TAO_ADCP_file)

lon_str = '110'
TAO_ADCP_file = '/data/SO3/edavenport/TAO_2012to2016_daily/ADCP_2012to2016_0N' + lon_str + 'W_daily.cdf' 
dsTAO_110 = xr.open_dataset(TAO_ADCP_file)

lon_str = '170'
TAO_ADCP_file = '/data/SO3/edavenport/TAO_2012to2016_daily/ADCP_2012to2016_0N' + lon_str + 'W_daily.cdf' 
dsTAO_170 = xr.open_dataset(TAO_ADCP_file)

dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])
# Out:
# /tmp/ipykernel_293364/2979973856.py:13: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])
# /tmp/ipykernel_293364/2979973856.py:13: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'depth' ('depth',) The recommendation is to set join explicitly for this case.
#   dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])
# /tmp/ipykernel_293364/2979973856.py:13: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'lon' ('lon',) The recommendation is to set join explicitly for this case.
#   dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])
# /tmp/ipykernel_293364/2979973856.py:13: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])
# /tmp/ipykernel_293364/2979973856.py:13: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])
# /tmp/ipykernel_293364/2979973856.py:13: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])
# /tmp/ipykernel_293364/2979973856.py:13: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   dsTAO = xr.merge([dsTAO_110,dsTAO_140,dsTAO_170])

# %%
dsTAO['depth'] = -1*dsTAO.depth
dsTAO = dsTAO.sel(time=slice('2012-09-01','2013-03-01')) # subset to sep 2012, mar 2013
dsTAO['u_1205'] = dsTAO.u_1205/100 # convert from cm/s to m/s
dsTAO['v_1206'] = dsTAO.v_1206/100 # convert from cm/s to m/s

# %%
dsTAO
# Out:
# <xarray.Dataset> Size: 543kB
# Dimensions:  (time: 182, depth: 62, lat: 1, lon: 3)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 2012-09-01T12:00:00 ... 2013-03-01T12:...
#   * depth    (depth) float32 248B -10.0 -15.0 -20.0 ... -305.0 -310.0 -315.0
#   * lat      (lat) float32 4B 0.0
#   * lon      (lon) float32 12B 190.0 220.0 250.0
# Data variables:
#     u_1205   (time, depth, lat, lon) float32 135kB nan nan nan ... nan nan nan
#     QU_5205  (time, depth, lat, lon) float32 135kB 0.0 0.0 0.0 ... 0.0 nan 0.0
#     v_1206   (time, depth, lat, lon) float32 135kB nan nan nan ... nan nan nan
#     QV_5206  (time, depth, lat, lon) float32 135kB 0.0 0.0 0.0 ... 0.0 nan 0.0
# Attributes:
#     platform_code:                0n110w
#     site_code:                    0n110w
#     wmo_platform_code:            32323
#     array:                        TAO/TRITON
#     Request_for_acknowledgement:  If you use these data in publications or pr...
#     Data_Source:                  Global Tropical Moored Buoy Array Project O...
#     File_info:                    Contact: Dai.C.McClurg@noaa.gov
#     missing_value:                1e+35
#     _FillValue:                   1e+35
#     CREATION_DATE:                09:59 14-AUG-2024

# %%
# rename TAO coords/dims so that depth is Z, lat is YC, lon is XC
dsTAO = dsTAO.rename({'depth':'Z','lat':'YC','lon':'XG'})
tpose_U_noTAO = ds_tpose_noTAO.UVEL.interp_like(dsTAO.u_1205).compute().squeeze()
tpose_U_TAO = ds_tpose_TAO.UVEL.interp_like(dsTAO.u_1205).compute().squeeze()

# rename TAO coords/dims so that depth is Z, lat is YC, lon is XC
dsTAO = dsTAO.rename({'XG':'XC','YC':'YG'})
tpose_V_noTAO = ds_tpose_noTAO.VVEL.interp_like(dsTAO.v_1206).compute().squeeze()
tpose_V_TAO = ds_tpose_TAO.VVEL.interp_like(dsTAO.v_1206).compute().squeeze()

# %%
def vertical_shear(U):
    # dU/dz on Z grid (units: s^-1)
    return U.differentiate('Z')

# %%
fig, ax = plt.subplots(
    figsize=(16, 12),
    nrows=2,
    ncols=3,
    sharey=True
)

XGs = [190.0, 220.0, 250.0]
titles = ['0N 170W', '0N 140W', '0N 110W']

for i, (xg, title) in enumerate(zip(XGs, titles)):

    # ------------------
    # Velocity (row 0)
    # ------------------
    ax[0, i].axvline(0, color='k', lw=0.5, ls='--')

    U_noTAO = tpose_U_noTAO.sel(XG=xg)
    U_withTAO = tpose_U_TAO.sel(XG=xg)

    U_noTAO.mean('time').plot(ax=ax[0, i], y='Z', label='TPOSE, no TAO')
    ax[0, i].fill_betweenx(
        U_noTAO.Z,
        U_noTAO.mean('time') - U_noTAO.std('time'),
        U_noTAO.mean('time') + U_noTAO.std('time'),
        alpha=0.1
    )

    U_withTAO.mean('time').plot(ax=ax[0, i], y='Z', label='TPOSE, with TAO')
    ax[0, i].fill_betweenx(
        U_withTAO.Z,
        U_withTAO.mean('time') - U_withTAO.std('time'),
        U_withTAO.mean('time') + U_withTAO.std('time'),
        alpha=0.1
    )

    TAO_mean = dsTAO.u_1205.sel(XC=xg).mean('time').squeeze()
    TAO_std  = dsTAO.u_1205.sel(XC=xg).std('time').squeeze()

    TAO_mean.plot(ax=ax[0, i], y='Z', marker='o', label='TAO')
    ax[0, i].fill_betweenx(
        dsTAO.Z, TAO_mean - TAO_std, TAO_mean + TAO_std,
        alpha=0.1
    )

    ax[0, i].set_title('')
    ax[0, i].set_ylim(-250, -20)
    ax[0, i].set_xlim(-0.75, 1.5)
    ax[0, i].set_xlabel('U (m s$^{-1}$)')
    ax[0, i].set_ylabel('')

    # ------------------
    # Shear (row 1)
    # ------------------
    ax[1, i].axvline(0, color='k', lw=0.5, ls='--')

    dUdz_noTAO   = vertical_shear(U_noTAO)
    dUdz_withTAO = vertical_shear(U_withTAO)
    dUdz_TAO     = vertical_shear(dsTAO.u_1205.sel(XC=xg))

    # Means
    m_noTAO   = dUdz_noTAO.mean('time')
    m_withTAO = dUdz_withTAO.mean('time')
    m_TAO     = dUdz_TAO.mean('time').squeeze()

    # STDs
    s_noTAO   = dUdz_noTAO.std('time')
    s_withTAO = dUdz_withTAO.std('time')
    s_TAO     = dUdz_TAO.std('time').squeeze()

    # Plot means
    m_noTAO.plot(ax=ax[1, i], y='Z', label='TPOSE, no TAO')
    m_withTAO.plot(ax=ax[1, i], y='Z', label='TPOSE, with TAO')
    m_TAO.plot(ax=ax[1, i], y='Z', marker='o', label='TAO')

    # Shading
    ax[1, i].fill_betweenx(
        m_noTAO.Z,
        m_noTAO - s_noTAO,
        m_noTAO + s_noTAO,
        alpha=0.1
    )

    ax[1, i].fill_betweenx(
        m_withTAO.Z,
        m_withTAO - s_withTAO,
        m_withTAO + s_withTAO,
        alpha=0.1
    )

    ax[1, i].fill_betweenx(
        dsTAO.Z,
        m_TAO - s_TAO,
        m_TAO + s_TAO,
        alpha=0.1
    )

    ax[1, i].set_title('')
    ax[1, i].set_ylim(-250, -20)
    ax[1, i].set_xlim(-0.03, 0.03)
    ax[1, i].set_xlabel(r'$\partial U / \partial z$ (s$^{-1}$)')
    ax[1, i].set_ylabel('')

    # Set title in upper right corner of each subplot
    for r in [0, 1]:
        ax[r, i].text(
            0.97, 0.97, title,
            transform=ax[r, i].transAxes,
            ha='right', va='top',
            fontsize=16,
            bbox=dict(
                boxstyle='round,pad=0.25',
                facecolor='white',
                edgecolor='k',
                linewidth=0.5,
                alpha=0.9
            )
        )


ax[0, 0].set_ylabel('Depth (m)')
ax[1, 0].set_ylabel('Depth (m)')

ax[0, 2].legend(loc='lower right', framealpha=1)
ax[1, 2].legend(loc='lower right', framealpha=1)

plt.tight_layout()
fig.savefig(foldername + 'U_and_shear_mean_prof.png')
# Out:
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,

# %%
fig, ax = plt.subplots(
    figsize=(16, 12),
    nrows=2,
    ncols=3,
    sharey=True
)

XGs = [190.0, 220.0, 250.0]
titles = ['0N 170W', '0N 140W', '0N 110W']

for i, (xg, title) in enumerate(zip(XGs, titles)):

    # ------------------
    # Velocity (row 0)
    # ------------------
    ax[0, i].axvline(0, color='k', lw=0.5, ls='--')

    V_noTAO = tpose_V_noTAO.sel(XC=xg)
    V_withTAO = tpose_V_TAO.sel(XC=xg)

    V_noTAO.mean('time').plot(ax=ax[0, i], y='Z', label='TPOSE, no TAO')
    ax[0, i].fill_betweenx(
        V_noTAO.Z,
        V_noTAO.mean('time') - V_noTAO.std('time'),
        V_noTAO.mean('time') + V_noTAO.std('time'),
        alpha=0.1
    )

    V_withTAO.mean('time').plot(ax=ax[0, i], y='Z', label='TPOSE, with TAO')
    ax[0, i].fill_betweenx(
        V_withTAO.Z,
        V_withTAO.mean('time') - V_withTAO.std('time'),
        V_withTAO.mean('time') + V_withTAO.std('time'),
        alpha=0.1
    )

    TAO_mean = dsTAO.v_1206.sel(XC=xg).mean('time').squeeze()
    TAO_std  = dsTAO.v_1206.sel(XC=xg).std('time').squeeze()

    TAO_mean.plot(ax=ax[0, i], y='Z', marker='o', label='TAO')
    ax[0, i].fill_betweenx(
        dsTAO.Z, TAO_mean - TAO_std, TAO_mean + TAO_std,
        alpha=0.1
    )

    ax[0, i].set_title('')
    ax[0, i].set_ylim(-250, -20)
    ax[0, i].set_xlim(-0.35, 0.35)
    ax[0, i].set_xlabel('V (m s$^{-1}$)')
    ax[0, i].set_ylabel('')

    # ------------------
    # Shear (row 1)
    # ------------------
    ax[1, i].axvline(0, color='k', lw=0.5, ls='--')

    dVdz_noTAO   = vertical_shear(V_noTAO)
    dVdz_withTAO = vertical_shear(V_withTAO)
    dVdz_TAO     = vertical_shear(dsTAO.v_1206.sel(XC=xg))

    # Means
    m_noTAO   = dVdz_noTAO.mean('time')
    m_withTAO = dVdz_withTAO.mean('time')
    m_TAO     = dVdz_TAO.mean('time').squeeze()

    # STDs
    s_noTAO   = dVdz_noTAO.std('time')
    s_withTAO = dVdz_withTAO.std('time')
    s_TAO     = dVdz_TAO.std('time').squeeze()

    # Plot means
    m_noTAO.plot(ax=ax[1, i], y='Z', label='TPOSE, no TAO')
    m_withTAO.plot(ax=ax[1, i], y='Z', label='TPOSE, with TAO')
    m_TAO.plot(ax=ax[1, i], y='Z', marker='o', label='TAO')

    # Shading
    ax[1, i].fill_betweenx(
        m_noTAO.Z,
        m_noTAO - s_noTAO,
        m_noTAO + s_noTAO,
        alpha=0.1
    )

    ax[1, i].fill_betweenx(
        m_withTAO.Z,
        m_withTAO - s_withTAO,
        m_withTAO + s_withTAO,
        alpha=0.1
    )

    ax[1, i].fill_betweenx(
        dsTAO.Z,
        m_TAO - s_TAO,
        m_TAO + s_TAO,
        alpha=0.1
    )

    ax[1, i].set_title('')
    ax[1, i].set_ylim(-250, -20)
    ax[1, i].set_xlim(-0.012, 0.012)
    ax[1, i].set_xlabel(r'$\partial V / \partial z$ (s$^{-1}$)')
    ax[1, i].set_ylabel('')

    # Set title in upper right corner of each subplot
    for r in [0, 1]:
        ax[r, i].text(
            0.97, 0.97, title,
            transform=ax[r, i].transAxes,
            ha='right', va='top',
            fontsize=16,
            bbox=dict(
                boxstyle='round,pad=0.25',
                facecolor='white',
                edgecolor='k',
                linewidth=0.5,
                alpha=0.9
            )
        )


ax[0, 0].set_ylabel('Depth (m)')
ax[1, 0].set_ylabel('Depth (m)')

ax[0, 2].legend(loc='lower right', framealpha=1)
ax[1, 2].legend(loc='lower right', framealpha=1)

plt.tight_layout()
fig.savefig(foldername + 'V_and_shear_mean_prof.png')
# Out:
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/numpy/lib/_nanfunctions_impl.py:2015: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 2026-02-12 12:44:19,057 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f00a387b740>, <Task finished name='Task-135053' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,065 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f00adc67600>, <Task finished name='Task-135057' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,071 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f00ad123ce0>, <Task finished name='Task-135059' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,078 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f00adc3be20>, <Task finished name='Task-135062' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,084 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f2703e440e0>, <Task finished name='Task-138252' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,092 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f2702e5e020>, <Task finished name='Task-138254' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,100 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f2701e999e0>, <Task finished name='Task-138257' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,107 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f2701e9a480>, <Task finished name='Task-138259' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,343 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f94cdd84400>, <Task finished name='Task-151491' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,351 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f94cdd86020>, <Task finished name='Task-151493' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,358 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f94cdd84ae0>, <Task finished name='Task-151497' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,365 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f94cc4ab6a0>, <Task finished name='Task-151498' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,401 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fa631bd20c0>, <Task finished name='Task-119316' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,408 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fa627a72c00>, <Task finished name='Task-119317' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,414 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fa6317c1120>, <Task finished name='Task-119319' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,422 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fa6580cf560>, <Task finished name='Task-119322' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,487 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f43f6554b80>, <Task finished name='Task-129096' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,494 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f43fc39db20>, <Task finished name='Task-129097' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:19,502 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f43f5cb5e40>, <Task finished name='Task-129100' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:19,508 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f43f5cb7920>, <Task finished name='Task-129102' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:19,599 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7fabc62d47c0>, <Task finished name='Task-126091' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
# ...
# 2026-02-12 12:44:20,542 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f03f94891c0>, <Task finished name='Task-146608' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:20,549 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f03efe0d620>, <Task finished name='Task-146610' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:20,556 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7f0402c74220>, <Task finished name='Task-146611' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8
# 2026-02-12 12:44:21,435 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7efdd8d4e980>, <Task finished name='Task-121085' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:21,442 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7efdcf3c77e0>, <Task finished name='Task-121086' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7002586286238287176,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.07 EiB for an array with shape (7002586286238287176,) and data type uint8
# 2026-02-12 12:44:21,450 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7efdcf3c76a0>, <Task finished name='Task-121088' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((8299622978920990024,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 7.20 EiB for an array with shape (8299622978920990024,) and data type uint8
# 2026-02-12 12:44:21,459 - tornado.application - ERROR - Exception in callback functools.partial(<function TCPServer._handle_connection.<locals>.<lambda> at 0x7efdce7d4180>, <Task finished name='Task-121093' coro=<BaseTCPListener._handle_stream() done, defined at /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py:655> exception=MemoryError((7867277414693422408,), dtype('uint8'))>)
# Traceback (most recent call last):
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/tornado/tcpserver.py", line 387, in <lambda>
#     gen.convert_yielded(future), lambda f: f.result()
#                                            ^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 667, in _handle_stream
#     await self.on_connection(comm)
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 288, in on_connection
#     return await super().on_connection(comm, handshake_overrides)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/core.py", line 267, in on_connection
#     handshake = await comm.read()
#                 ^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 228, in read
#     frames_nosplit = await read_bytes_rw(stream, frames_nosplit_nbytes)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/comm/tcp.py", line 360, in read_bytes_rw
#     buf = host_array(n)
#           ^^^^^^^^^^^^^
#   File "/home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/distributed/protocol/utils.py", line 29, in host_array
#     return numpy.empty((n,), dtype="u1").data
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 6.82 EiB for an array with shape (7867277414693422408,) and data type uint8

# %%
client.shutdown()
cluster.close()
client.close()
