# %%
# get diag from previous window output 
import xarray as xr
from xmitgcm import open_mdsdataset

data_dir = '/data/SO3/edavenport/tpose6/mar2013/run_iter16/'
grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

# grab the last iteration
iter = 8784 

tpose_ds = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=iter,prefix='diag_state')
# Out:
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/xmitgcm/mds_store.py:289: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds['time'] = xr.decode_cf(ds[['time']])['time']

# %%
month_name = 'jul012013'
folder_name = 'model_setup/forecast_IC/' + month_name + '/'

# %%
tpose_ds = tpose_ds.drop_vars(['DRHODR','WVEL'])

# %%
tpose_ds.data_vars
# Out:
# Data variables:
#     THETA    (time, Z, YC, XC) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>
#     SALT     (time, Z, YC, XC) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>
#     UVEL     (time, Z, YC, XG) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>
#     VVEL     (time, Z, YG, XC) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>

# %%
for v in tpose_ds.data_vars:
    arr = tpose_ds[v].values
    # print(folder_name + f'{v}_assim_jan2013.data')
    arr.astype('>f4').tofile(folder_name + f'{v}_tpose_Vel_'+ month_name +'.data')

# %%
data_dir = '/data/SO3/averdy/TPOSE6/may2013/diags_daily/'
# data_dir = '/data/SO6/TPOSE_diags/tpose6/sep2012/diags_iter7_daily/' 
grid_dir = '/data/SO6/TPOSE_diags/tpose6/grid_6/'

# grab the last iteration
iter = 8640 #

tpose_ds_old = open_mdsdataset(data_dir=data_dir,grid_dir=grid_dir,iters=iter,prefix='diag_state')
# Out:
# /home/edavenport/miniforge3/envs/tpose/lib/python3.12/site-packages/xmitgcm/mds_store.py:289: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds['time'] = xr.decode_cf(ds[['time']])['time']

# %%
tpose_ds_old = tpose_ds_old.drop_vars(['DRHODR','WVEL','PHIHYD'])

# %%
tpose_ds_old
# Out:
# <xarray.Dataset> Size: 795MB
# Dimensions:  (time: 1, XC: 1128, YC: 336, XG: 1128, YG: 336, Z: 66, Zp1: 67,
#               Zu: 66, Zl: 66)
# Coordinates: (12/34)
#   * time     (time) timedelta64[ns] 8B 02:24:00
#   * XC       (XC) >f4 5kB 104.1 104.2 104.4 104.6 ... 291.4 291.6 291.8 291.9
#   * YC       (YC) >f4 1kB -25.92 -25.75 -25.58 -25.42 ... 29.58 29.75 29.92
#   * XG       (XG) >f4 5kB 104.0 104.2 104.3 104.5 ... 291.3 291.5 291.7 291.8
#   * YG       (YG) >f4 1kB -26.0 -25.83 -25.67 -25.5 ... 29.33 29.5 29.67 29.83
#   * Z        (Z) >f4 264B -1.0 -3.0 -5.0 -7.0 ... -4.75e+03 -5.25e+03 -5.75e+03
#     ...       ...
#     maskS    (Z, YG, XC) bool 25MB dask.array<chunksize=(66, 336, 1128), meta=np.ndarray>
#     dxF      (YC, XC) >f4 2MB dask.array<chunksize=(336, 1128), meta=np.ndarray>
#     rhoRef   (Z) >f4 264B 1.021e+03 1.021e+03 1.021e+03 ... 1.043e+03 1.045e+03
#     dyF      (YC, XC) >f4 2MB dask.array<chunksize=(336, 1128), meta=np.ndarray>
#     dxV      (YG, XG) >f4 2MB dask.array<chunksize=(336, 1128), meta=np.ndarray>
#     dyU      (YG, XG) >f4 2MB dask.array<chunksize=(336, 1128), meta=np.ndarray>
# Data variables:
#     THETA    (time, Z, YC, XC) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>
#     SALT     (time, Z, YC, XC) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>
#     UVEL     (time, Z, YC, XG) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>
#     VVEL     (time, Z, YG, XC) >f4 100MB dask.array<chunksize=(1, 66, 336, 1128), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     title:        netCDF wrapper of MITgcm MDS binary data
#     source:       MITgcm
#     history:      Created by calling `open_mdsdataset(data_dir='/data/SO3/ave...

# %%
for v in tpose_ds_old.data_vars:
    arr = tpose_ds_old[v].values
    # print(folder_name + f'{v}_assim_jan2013.data')
    arr.astype('>f4').tofile(folder_name + f'{v}_tpose_noVel_'+ month_name +'.data')
