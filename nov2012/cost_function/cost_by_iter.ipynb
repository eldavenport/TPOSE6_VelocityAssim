# %%
import matplotlib.pyplot as plt
import cmocean.cm as cmo
import xarray as xr
import numpy as np
import mitgcm_assim.cost as cost

# Read all costfunction* files in current directory
ds = cost.read_costfunction('/data/SO3/edavenport/tpose6/nov2012/run_ad_temp/')
folder_name = 'nov2012/cost_function/'

# %%
ds.cost.sel(dataset='fc')
# Out:
# <xarray.DataArray 'cost' (iter: 1)> Size: 8B
# array([10335120.409359])
# Coordinates:
#   * iter     (iter) int64 8B 4
#     dataset  <U28 112B 'fc'

# %% [markdown]
# ### Combine 2012 and 2013 costs

# %%
# define dataset names
d2012 = 'TAO_WO_2012_CTD_daily_prof_T'
d2013 = 'TAO_WO_2013_CTD_daily_prof_T'
new  = 'TAO_WO_CTD_daily_prof_T'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# define dataset names
d2012 = 'TAO_WO_2012_CTD_daily_prof_S'
d2013 = 'TAO_WO_2013_CTD_daily_prof_S'
new  = 'TAO_WO_CTD_daily_prof_S'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# define dataset names
d2012 = 'TAO_WO_2012_ADCP_v2_prof_U'
d2013 = 'TAO_WO_2013_ADCP_prof_U'
new  = 'TAO_WO_ADCP_prof_U'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# define dataset names
d2012 = 'TAO_WO_2012_ADCP_v2_prof_V'
d2013 = 'TAO_WO_2013_ADCP_prof_V'
new  = 'TAO_WO_ADCP_prof_V'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# define dataset names
d2012 = 'TAO_WO_2012_CUR_v2_prof_U'
d2013 = 'TAO_WO_2013_CUR_prof_U'
new  = 'TAO_WO_CUR_prof_U'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# define dataset names
d2012 = 'TAO_WO_2012_CUR_v2_prof_V'
d2013 = 'TAO_WO_2013_CUR_prof_V'
new  = 'TAO_WO_CUR_prof_V'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# %%
# Gliders 
# define dataset names
d2012 = 'WOD_TP_2012_GLD_w_prof_T'
d2013 = 'WOD_TP_2013_GLD_qc_prof_T'
new  = 'WOD_TP_GLD_w_prof_T'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# Gliders 
# define dataset names
d2012 = 'WOD_TP_2012_GLD_w_prof_S'
d2013_A = 'WOD_TP_2013_GLD_w_prof_S'
new  = 'WOD_TP_GLD_w_prof_S'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# XBT 
# define dataset names
d2012 = 'SIO_TP_2012_XBT_w_prof_T'
d2013 = 'SIO_TP_2013_XBT_w_prof_T'
new  = 'SIO_TP_XBT_w_prof_T'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

#  HDO CTD
# define dataset names
d2012 = 'HDO_TP_2012_CTD_w_prof_T'
d2013 = 'HDO_TP_2013_CTD_w_prof_T'
new  = 'HDO_TP_CTD_w_prof_T'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

d2012 = 'HDO_TP_2012_CTD_w_prof_S'
d2013 = 'HDO_TP_2013_CTD_w_prof_S'
new  = 'HDO_TP_CTD_w_prof_S'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

# USGO PFL
d2012 = 'USGO_TP_2012_PFL_D_w_prof_T'
d2013 = 'USGO_TP_2013_PFL_D_w_prof_T'
new  = 'USGO_TP_PFL_D_w_prof_T'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs

d2012 = 'USGO_TP_2012_PFL_D_w_prof_S'
d2013 = 'USGO_TP_2013_PFL_D_w_prof_S'
new  = 'USGO_TP_PFL_D_w_prof_S'

# compute sums
new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')

# extend dataset coordinate to include the new one
new_ds_list = list(ds.dataset.values) + [new]
ds = ds.reindex(dataset=new_ds_list)

ds.cost.loc[dict(dataset=new)] = new_cost
ds.n_obs.loc[dict(dataset=new)] = new_nobs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 8
#       5 new  = 'WOD_TP_GLD_w_prof_T'
#       7 # compute sums
# ----> 8 new_cost = ds.cost.sel(dataset=[d2012, d2013]).sum(dim='dataset')
#       9 new_nobs = ds.n_obs.sel(dataset=[d2012, d2013]).sum(dim='dataset')
#      11 # extend dataset coordinate to include the new one
#
# File ~/miniforge3/envs/tpose/lib/python3.12/site-packages/xarray/core/dataarray.py:1717, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1601 def sel(
#    1602     self,
#    1603     indexers: Mapping[Any, Any] | None = None,
#    (...)   1607     **indexers_kwargs: Any,
#    1608 ) -> Self:
#    1609     """Return a new DataArray whose data is given by selecting index
#    1610     labels along the specified dimension(s).
#    1611
#    (...)   1715     Dimensions without coordinates: points
# ...

# %% [markdown]
# ### Plotting

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ds.cost.sel(dataset='fc').plot(marker='o',markersize=4,ax=ax)
ax.set_yscale('log')
ax.set_title('Total Cost')
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'total_cost.png')

# %%
ds.dataset
# Out:
# <xarray.DataArray 'dataset' (dataset: 46)> Size: 5kB
# array(['HDO_TP_2012_CTD_w_prof_S', 'HDO_TP_2012_CTD_w_prof_T',
#        'HDO_TP_2013_CTD_w_prof_S', 'HDO_TP_2013_CTD_w_prof_T',
#        'SIO_TP_2012_XBT_w_prof_T', 'SIO_TP_2013_XBT_w_prof_T',
#        'TAO_WO_2012_ADCP_v2_prof_U', 'TAO_WO_2012_ADCP_v2_prof_V',
#        'TAO_WO_2012_CTD_daily_prof_S', 'TAO_WO_2012_CTD_daily_prof_T',
#        'TAO_WO_2012_CUR_v2_prof_U', 'TAO_WO_2012_CUR_v2_prof_V',
#        'TAO_WO_2013_ADCP_prof_U', 'TAO_WO_2013_ADCP_prof_V',
#        'TAO_WO_2013_CTD_daily_prof_S', 'TAO_WO_2013_CTD_daily_prof_T',
#        'TAO_WO_2013_CUR_prof_U', 'TAO_WO_2013_CUR_prof_V',
#        'USGO_TP_2012_PFL_D_w_prof_S', 'USGO_TP_2012_PFL_D_w_prof_T',
#        'USGO_TP_2013_PFL_D_w_prof_S', 'USGO_TP_2013_PFL_D_w_prof_T',
#        'WOD_TP_2012_GLD_w_prof_S', 'WOD_TP_2012_GLD_w_prof_T',
#        'WOD_TP_2012_XBT_w_prof_T', 'WOD_TP_2013_GLD_A_w_prof_S',
#        'WOD_TP_2013_GLD_A_w_prof_T', 'WOD_TP_2013_GLD_B_w_prof_S',
# ...

# %%
fig, ax = plt.subplots(figsize=(9, 6))
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_U')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='ADCP_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_V')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='ADCP_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_U')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='CUR_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_V')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='CUR_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_T')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='CTD_daily_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_S')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='CTD_daily_prof_S',marker='o',markersize=4)
ax.set_title('Cost by Dataset')
ax.set_ylabel('% of Total Cost')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.04), ncol=3)
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'cost_relative_TAO.png')

# %%
fig, ax = plt.subplots(figsize=(9, 6))
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_T')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='GLD_w_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_S')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='GLD_w_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_CTD_w_prof_T')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='HDO_CTD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_CTD_w_prof_S')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='HDO_CTD_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='USGO_TP_PFL_D_w_prof_T')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='USGO_PFL_D_prof_T',marker='o',linestyle='--',markersize=4)
(ds.cost.sel(dataset='USGO_TP_PFL_D_w_prof_S')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='USGO_PFL_D_prof_S',marker='o',linestyle='--',markersize=4)
(ds.cost.sel(dataset='SIO_TP_XBT_w_prof_T')/ds.cost.sel(dataset='fc')*100).plot(ax=ax,label='SIO_XBT_prof_T',marker='o',linestyle='--',markersize=4)
ax.set_title('Cost by Dataset')
ax.set_ylabel('% of Total Cost')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.04), ncol=3)
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'cost_relative_OTHER.png')

# %%
fig, ax = plt.subplots(figsize=(10, 8))
(ds.n_obs.sel(dataset='TAO_WO_ADCP_prof_U')).plot(ax=ax,label='ADCP_prof_U',marker='o',markersize=4)
(ds.n_obs.sel(dataset='TAO_WO_ADCP_prof_V')).plot(ax=ax,label='ADCP_prof_V',marker='o',markersize=4)
(ds.n_obs.sel(dataset='TAO_WO_CUR_prof_U')).plot(ax=ax,label='CUR_prof_U',marker='o',markersize=4)
(ds.n_obs.sel(dataset='TAO_WO_CUR_prof_V')).plot(ax=ax,label='CUR_prof_V',marker='o',markersize=4)
(ds.n_obs.sel(dataset='TAO_WO_CTD_daily_prof_T')).plot(ax=ax,label='CTD_daily_prof_T',marker='o',markersize=4)
(ds.n_obs.sel(dataset='TAO_WO_CTD_daily_prof_S')).plot(ax=ax,label='CTD_daily_prof_S',marker='o',markersize=4)
(ds.n_obs.sel(dataset='WOD_TP_GLD_w_prof_T')).plot(ax=ax,label='GLD_w_prof_T',marker='o',markersize=4)
(ds.n_obs.sel(dataset='WOD_TP_GLD_w_prof_S')).plot(ax=ax,label='GLD_w_prof_S',marker='o',markersize=4)
(ds.n_obs.sel(dataset='HDO_TP_CTD_w_prof_T')).plot(ax=ax,label='HDO_CTD_prof_T',marker='o',markersize=4)
(ds.n_obs.sel(dataset='HDO_TP_CTD_w_prof_S')).plot(ax=ax,label='HDO_CTD_prof_S',marker='o',markersize=4)
(ds.n_obs.sel(dataset='USGO_TP_PFL_D_w_prof_T')).plot(ax=ax,label='USGO_PFL_D_prof_T',marker='o',linestyle='--',markersize=4)
(ds.n_obs.sel(dataset='USGO_TP_PFL_D_w_prof_S')).plot(ax=ax,label='USGO_PFL_D_prof_S',marker='o',linestyle='--',markersize=4)
(ds.n_obs.sel(dataset='SIO_TP_XBT_w_prof_T')).plot(ax=ax,label='SIO_XBT_prof_T',marker='o',linestyle='--',markersize=4)
ax.set_title('N Obs by Dataset')
ax.set_ylabel('# Obs')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.04), ncol=4)
ax.set_yscale('log')
plt.tight_layout()
fig.savefig(folder_name + 'N_obs.png')

# %%
fig, ax = plt.subplots(figsize=(10, 8))
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_U')).plot(ax=ax,label='ADCP_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_V')).plot(ax=ax,label='ADCP_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_U')).plot(ax=ax,label='CUR_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_V')).plot(ax=ax,label='CUR_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_T')).plot(ax=ax,label='CTD_daily_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_S')).plot(ax=ax,label='CTD_daily_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_T')).plot(ax=ax,label='GLD_w_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_S')).plot(ax=ax,label='GLD_w_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_CTD_w_prof_T')).plot(ax=ax,label='HDO_CTD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_CTD_w_prof_S')).plot(ax=ax,label='HDO_CTD_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='USGO_TP_PFL_D_w_prof_T')).plot(ax=ax,label='USGO_PFL_D_prof_T',marker='o',linestyle='--',markersize=4)
(ds.cost.sel(dataset='USGO_TP_PFL_D_w_prof_S')).plot(ax=ax,label='USGO_PFL_D_prof_S',marker='o',linestyle='--',markersize=4)
(ds.cost.sel(dataset='SIO_TP_XBT_w_prof_T')).plot(ax=ax,label='SIO_XBT_prof_T',marker='o',linestyle='--',markersize=4)
ax.set_title('Cost by Dataset')
ax.set_ylabel('# Obs')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.04), ncol=4)
ax.set_yscale('log')
plt.tight_layout()
fig.savefig(folder_name + 'cost_not_norm.png')

# %%
fig, ax = plt.subplots(figsize=(10, 7))
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_U')/ds.n_obs.sel(dataset='TAO_WO_ADCP_prof_U')).plot(ax=ax,label='ADCP_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_V')/ds.n_obs.sel(dataset='TAO_WO_ADCP_prof_V')).plot(ax=ax,label='ADCP_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_U')/ds.n_obs.sel(dataset='TAO_WO_CUR_prof_U')).plot(ax=ax,label='CUR_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_V')/ds.n_obs.sel(dataset='TAO_WO_CUR_prof_V')).plot(ax=ax,label='CUR_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_T')/ds.n_obs.sel(dataset='TAO_WO_CTD_daily_prof_T')).plot(ax=ax,label='CTD_daily_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_S')/ds.n_obs.sel(dataset='TAO_WO_CTD_daily_prof_S')).plot(ax=ax,label='CTD_daily_prof_S',marker='o',markersize=4)
ax.set_title('TAO Moorings Normalized Cost')
ax.set_ylabel('Cost / # of Observations')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.04), ncol=3)
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'TAO_mooring_cost.png')

# %%
fig, ax = plt.subplots(figsize=(9, 7))
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_U')/ds.n_obs.sel(dataset='TAO_WO_ADCP_prof_U')).plot(ax=ax,label='ADCP_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_ADCP_prof_V')/ds.n_obs.sel(dataset='TAO_WO_ADCP_prof_V')).plot(ax=ax,label='ADCP_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_U')/ds.n_obs.sel(dataset='TAO_WO_CUR_prof_U')).plot(ax=ax,label='CUR_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CUR_prof_V')/ds.n_obs.sel(dataset='TAO_WO_CUR_prof_V')).plot(ax=ax,label='CUR_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_T')/ds.n_obs.sel(dataset='TAO_WO_CTD_daily_prof_T')).plot(ax=ax,label='CTD_daily_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_CTD_daily_prof_S')/ds.n_obs.sel(dataset='TAO_WO_CTD_daily_prof_S')).plot(ax=ax,label='CTD_daily_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_CTD_w_prof_T')/ds.n_obs.sel(dataset='HDO_TP_CTD_w_prof_T')).plot(ax=ax,label='HDO_CTD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_CTD_w_prof_S')/ds.n_obs.sel(dataset='HDO_TP_CTD_w_prof_S')).plot(ax=ax,label='HDO_CTD_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_T')/ds.n_obs.sel(dataset='WOD_TP_GLD_w_prof_T')).plot(ax=ax,label='WOD_GLD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_S')/ds.n_obs.sel(dataset='WOD_TP_GLD_w_prof_S')).plot(ax=ax,label='WOD_GLD_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='USGO_TP_PFL_D_w_prof_T')/ds.n_obs.sel(dataset='USGO_TP_PFL_D_w_prof_T')).plot(ax=ax,label='USGO_PFL_prof_T',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='USGO_TP_PFL_D_w_prof_S')/ds.n_obs.sel(dataset='USGO_TP_PFL_D_w_prof_S')).plot(ax=ax,label='USGO_PFL_prof_S',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='SIO_TP_XBT_w_prof_T')/ds.n_obs.sel(dataset='SIO_TP_XBT_w_prof_T')).plot(ax=ax,label='SIO_XBT_prof_T',linestyle='--',marker='o',markersize=4)
ax.set_title('Profiles Normalized Cost')
ax.set_ylabel('Cost / # of Observations')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.04), ncol=3)
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'prof_cost.png')

# %%
fig, ax = plt.subplots(figsize=(9, 7))
(ds.cost.sel(dataset='WOD_TP_2012_GLD_w_prof_T')/ds.n_obs.sel(dataset='WOD_TP_2012_GLD_w_prof_T')).plot(ax=ax,label='2012 WOD_GLD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_2013_GLD_A_w_prof_T')/ds.n_obs.sel(dataset='WOD_TP_2013_GLD_A_w_prof_T')).plot(ax=ax,label='2013 WOD_GLD_A_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_2013_GLD_B_w_prof_T')/ds.n_obs.sel(dataset='WOD_TP_2013_GLD_B_w_prof_T')).plot(ax=ax,label='2013 WOD_GLD_B_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_2012_GLD_w_prof_S')/ds.n_obs.sel(dataset='WOD_TP_2012_GLD_w_prof_S')).plot(ax=ax,label='2012 WOD_GLD_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_2013_GLD_A_w_prof_S')/ds.n_obs.sel(dataset='WOD_TP_2013_GLD_A_w_prof_S')).plot(ax=ax,label='2013 WOD_GLD_A_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_2013_GLD_B_w_prof_S')/ds.n_obs.sel(dataset='WOD_TP_2013_GLD_B_w_prof_S')).plot(ax=ax,label='2013 WOD_GLD_B_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_T')/ds.n_obs.sel(dataset='WOD_TP_GLD_w_prof_T')).plot(ax=ax,label='WOD_GLD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_GLD_w_prof_S')/ds.n_obs.sel(dataset='WOD_TP_GLD_w_prof_S')).plot(ax=ax,label='WOD_GLD_prof_S',marker='o',markersize=4)
ax.set_title('Profiles Normalized Cost')
ax.set_ylabel('Cost / # of Observations')
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.04), ncol=3)
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'glider_cost.png')

# %%
glider_set = ['WOD_TP_2012_GLD_w_prof_T','WOD_TP_2012_GLD_w_prof_S','WOD_TP_2013_GLD_A_w_prof_T','WOD_TP_2013_GLD_A_w_prof_S','WOD_TP_2013_GLD_B_w_prof_T','WOD_TP_2013_GLD_B_w_prof_S']
glider_ds = ds.cost.sel(dataset=glider_set).isel(iter=-1)

fig, ax = plt.subplots(figsize=(12, 5))
series = glider_ds.to_series()
series.plot.bar(ax=ax,rot=90)
fig.savefig(folder_name + 'glider_bar_chart.png')

# %%
fig, ax = plt.subplots(figsize=(9, 7))
(ds.cost.sel(dataset='sshv4-gfo')/ds.n_obs.sel(dataset='sshv4-gfo')).plot(ax=ax,label='sshv4-gfo',marker='o',markersize=4)
(ds.cost.sel(dataset='sshv4-mdt')/ds.n_obs.sel(dataset='sshv4-mdt')).plot(ax=ax,label='sshv4-mdt',marker='o',markersize=4)
(ds.cost.sel(dataset='sshv4-tp')/ds.n_obs.sel(dataset='sshv4-tp')).plot(ax=ax,label='sshv4-tp',marker='o',markersize=4)
(ds.cost.sel(dataset='sst-MW')/ds.n_obs.sel(dataset='sst-MW')).plot(ax=ax,label='sst-MW',marker='o',markersize=4)
ax.set_title('ECCO Normalized Cost')
ax.legend()
ax.set_ylabel('Cost / # of Observations')
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'ecco_cost.png')

# %%
fig, ax = plt.subplots(figsize=(9, 7))
(ds.cost.sel(dataset='TAO_WO_2012_ADCP_prof_U')/ds.n_obs.sel(dataset='TAO_WO_2012_ADCP_prof_U')).plot(ax=ax,label='ADCP_prof_U',marker='o',markersize=4)
(ds.cost.sel(dataset='TAO_WO_2012_ADCP_prof_V')/ds.n_obs.sel(dataset='TAO_WO_2012_ADCP_prof_V')).plot(ax=ax,label='ADCP_prof_V',marker='o',markersize=4)
(ds.cost.sel(dataset='NODC_TP_2012_MRB_w_prof_T')/ds.n_obs.sel(dataset='NODC_TP_2012_MRB_w_prof_T')).plot(ax=ax,label='TAO_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='NODC_TP_2012_MRB_w_prof_S')/ds.n_obs.sel(dataset='NODC_TP_2012_MRB_w_prof_S')).plot(ax=ax,label='TAO_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_2012_CTD_w_prof_T')/ds.n_obs.sel(dataset='HDO_TP_2012_CTD_w_prof_T')).plot(ax=ax,label='HDO_CTD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='HDO_TP_2012_CTD_w_prof_S')/ds.n_obs.sel(dataset='HDO_TP_2012_CTD_w_prof_S')).plot(ax=ax,label='HDO_CTD_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_2012_GLD_w_prof_T')/ds.n_obs.sel(dataset='WOD_TP_2012_GLD_w_prof_T')).plot(ax=ax,label='WOD_GLD_prof_T',marker='o',markersize=4)
(ds.cost.sel(dataset='WOD_TP_2012_GLD_w_prof_S')/ds.n_obs.sel(dataset='WOD_TP_2012_GLD_w_prof_S')).plot(ax=ax,label='WOD_GLD_prof_S',marker='o',markersize=4)
(ds.cost.sel(dataset='USGO_TP_2012_PFL_D_w_prof_T')/ds.n_obs.sel(dataset='USGO_TP_2012_PFL_D_w_prof_T')).plot(ax=ax,label='USGO_PFL_prof_T',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='USGO_TP_2012_PFL_D_w_prof_S')/ds.n_obs.sel(dataset='USGO_TP_2012_PFL_D_w_prof_S')).plot(ax=ax,label='USGO_PFL_prof_S',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='SIO_TP_2012_XBT_w_prof_T')/ds.n_obs.sel(dataset='SIO_TP_2012_XBT_w_prof_T')).plot(ax=ax,label='SIO_XBT_prof_T',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='sshv4-gfo')/ds.n_obs.sel(dataset='sshv4-gfo')).plot(ax=ax,label='sshv4-gfo',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='sshv4-mdt')/ds.n_obs.sel(dataset='sshv4-mdt')).plot(ax=ax,label='sshv4-mdt',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='sshv4-tp')/ds.n_obs.sel(dataset='sshv4-tp')).plot(ax=ax,label='sshv4-tp',linestyle='--',marker='o',markersize=4)
(ds.cost.sel(dataset='sst-MW')/ds.n_obs.sel(dataset='sst-MW')).plot(ax=ax,label='sst-MW',linestyle='--',marker='o',markersize=4)
ax.set_title('All Obs Normalized Cost')
ax.set_ylabel('Cost / # of Observations')
ax.legend(ncol=2)
ax.set_xlim(0,ds.iter.max())
plt.tight_layout()
fig.savefig(folder_name + 'obs_cost.png')

# %%
fig, ax = plt.subplots(figsize=(9, 7))
((ds.cost.sel(dataset='xx_aqh')/ds.n_obs.sel(dataset='xx_aqh'))).plot(ax=ax,label='xx_aqh',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_atemp')/ds.n_obs.sel(dataset='xx_atemp'))).plot(ax=ax,label='xx_atemp',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_lwdown')/ds.n_obs.sel(dataset='xx_lwdown'))).plot(ax=ax,label='xx_lwdown',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_precip')/ds.n_obs.sel(dataset='xx_precip'))).plot(ax=ax,label='xx_precip',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_salt')/ds.n_obs.sel(dataset='xx_salt'))).plot(ax=ax,label='xx_salt',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_swdown')/ds.n_obs.sel(dataset='xx_swdown'))).plot(ax=ax,label='xx_swdown',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_theta')/ds.n_obs.sel(dataset='xx_theta'))).plot(ax=ax,label='xx_theta',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_uvel')/ds.n_obs.sel(dataset='xx_uvel'))).plot(ax=ax,label='xx_uvel',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_vvel')/ds.n_obs.sel(dataset='xx_vvel'))).plot(ax=ax,label='xx_vvel',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_uwind')/ds.n_obs.sel(dataset='xx_uwind'))).plot(ax=ax,label='xx_uwind',marker='o',markersize=4)
((ds.cost.sel(dataset='xx_vwind')/ds.n_obs.sel(dataset='xx_vwind'))).plot(ax=ax,label='xx_vwind',linestyle='--',marker='o',markersize=4)
ax.set_title('Normalized Control Effort')
ax.legend(ncol=2)
ax.set_yscale('log')
ax.set_xlim(1,ds.iter.max())
ax.set_ylabel('(cost/# ctrls)')
plt.tight_layout()
fig.savefig(folder_name + 'control_effort.png')
